# %% [markdown]
# # Leaflet cluster map of talk locations
#
# Assuming you are working in a Linux or Windows Subsystem for Linux environment, you may need to install some dependencies. Assuming a clean installation, the following will be needed:
#
# ```bash
# sudo apt install jupyter
# sudo apt install python3-pip
# pip install python-frontmatter getorg --upgrade
# ```
#
# After which you can run this from the `_talks/` directory, via:
#
# ```bash
#  jupyter nbconvert --to notebook --execute talkmap.ipynb --output talkmap_out.ipynb
# ```
#
# The `_talks/` directory contains `.md` files of all your talks. This scrapes the location YAML field from each `.md` file, geolocates it with `geopy/Nominatim`, and uses the `getorg` library to output data, HTML, and Javascript for a standalone cluster map.

# %%
# Start by installing the dependencies
# !pip install python-frontmatter getorg --upgrade
import frontmatter
import glob
import getorg
from geopy import Nominatim
from geopy.exc import GeocoderTimedOut
# Out:
# Requirement already satisfied: python-frontmatter in /home/vvinod/miniforge3/lib/python3.12/site-packages (1.1.0)
# Requirement already satisfied: getorg in /home/vvinod/miniforge3/lib/python3.12/site-packages (0.3.1)
# Requirement already satisfied: PyYAML in /home/vvinod/miniforge3/lib/python3.12/site-packages (from python-frontmatter) (6.0.2)
# Requirement already satisfied: geopy in /home/vvinod/miniforge3/lib/python3.12/site-packages (from getorg) (2.4.1)
# Requirement already satisfied: pygithub in /home/vvinod/miniforge3/lib/python3.12/site-packages (from getorg) (2.6.1)
# Requirement already satisfied: retrying in /home/vvinod/miniforge3/lib/python3.12/site-packages (from getorg) (1.3.4)
# Requirement already satisfied: geographiclib<3,>=1.52 in /home/vvinod/miniforge3/lib/python3.12/site-packages (from geopy->getorg) (2.1)
# Requirement already satisfied: pynacl>=1.4.0 in /home/vvinod/miniforge3/lib/python3.12/site-packages (from pygithub->getorg) (1.5.0)
# Requirement already satisfied: requests>=2.14.0 in /home/vvinod/miniforge3/lib/python3.12/site-packages (from pygithub->getorg) (2.32.3)
# Requirement already satisfied: pyjwt>=2.4.0 in /home/vvinod/miniforge3/lib/python3.12/site-packages (from pyjwt[crypto]>=2.4.0->pygithub->getorg) (2.10.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/vvinod/miniforge3/lib/python3.12/site-packages (from pygithub->getorg) (4.13.2)
# Requirement already satisfied: urllib3>=1.26.0 in /home/vvinod/miniforge3/lib/python3.12/site-packages (from pygithub->getorg) (2.3.0)
# Requirement already satisfied: Deprecated in /home/vvinod/miniforge3/lib/python3.12/site-packages (from pygithub->getorg) (1.2.18)
# Requirement already satisfied: six>=1.7.0 in /home/vvinod/miniforge3/lib/python3.12/site-packages (from retrying->getorg) (1.17.0)
# Requirement already satisfied: cryptography>=3.4.0 in /home/vvinod/miniforge3/lib/python3.12/site-packages (from pyjwt[crypto]>=2.4.0->pygithub->getorg) (44.0.2)
# Requirement already satisfied: cffi>=1.4.1 in /home/vvinod/miniforge3/lib/python3.12/site-packages (from pynacl>=1.4.0->pygithub->getorg) (1.17.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/vvinod/miniforge3/lib/python3.12/site-packages (from requests>=2.14.0->pygithub->getorg) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/vvinod/miniforge3/lib/python3.12/site-packages (from requests>=2.14.0->pygithub->getorg) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/vvinod/miniforge3/lib/python3.12/site-packages (from requests>=2.14.0->pygithub->getorg) (2025.1.31)
# Requirement already satisfied: wrapt<2,>=1.10 in /home/vvinod/miniforge3/lib/python3.12/site-packages (from Deprecated->pygithub->getorg) (1.17.2)
# Requirement already satisfied: pycparser in /home/vvinod/miniforge3/lib/python3.12/site-packages (from cffi>=1.4.1->pynacl>=1.4.0->pygithub->getorg) (2.22)
# Iywidgets and ipyleaflet support disabled. You must be in a Jupyter notebook to use this feature.
# Error raised:
# No module named 'ipywidgets'
# Check that you have enabled ipyleaflet in Jupyter with:
#     jupyter nbextension enable --py ipyleaflet

# %%
# Collect the Markdown files
g = glob.glob("_talks/*.md")

# %%
# Set the default timeout, in seconds
TIMEOUT = 10

# Prepare to geolocate
geocoder = Nominatim(user_agent="vivinvinod.github.io")
location_dict = {}
location = ""
permalink = ""
title = ""

# %%
# Perform geolocation
for file in g:
    # Read the file
    data = frontmatter.load(file)
    data = data.to_dict()

    # Press on if the location is not present
    if 'location' not in data:
        continue

    # Prepare the description
    title = data['title'].strip()
    venue = data['venue'].strip()
    location = data['location'].strip()
    description = f"{title}<br />{venue}; {location}"

    # Geocode the location and report the status
    try:
        location_dict[description] = geocoder.geocode(location, timeout=TIMEOUT)
        print(description, location_dict[description],'\n')
    except ValueError as ex:
        print(f"Error: geocode failed on input {location} with message {ex}")
    except GeocoderTimedOut as ex:
        print(f"Error: geocode timed out on input {location} with message {ex}")
    except Exception as ex:
        print(f"An unhandled exception occurred while processing input {location} with message {ex}")
# Out:
# Optimized Multi-Fidelity Machine Learning for Quantum Chemistry.<br />SPP-2363 Annual Meet; Jägerberg 1, 06108 Halle (Saale) Leopoldina, 1, Jägerberg, Neumarktviertel, Nördliche Innenstadt, Halle (Saale), Sachsen-Anhalt, 06108, Deutschland
#
# Multi-Fidelity Machine Learning for Excited State Energies.<br />Machine Learning and Quantum Computing for Quantum Molecular Dynamics - MLQCDyn; Université Gustave Eiffel, 5 Boulevard Descartes, 77420 Champs-sur-Marne, France Université Gustave Eiffel - Bâtiment Copernic, 5, Boulevard Descartes, Cité Descartes, Champs-sur-Marne, Torcy, Seine-et-Marne, France métropolitaine, 77420, France
#
# Small area estimation methods for NUTS3 level poverty estimation in Italy.<br />Small Area Estimation Method Seminar, Scuola S’ant Anna; P.zza Martiri della Libertà, 33 - 56127 - Pisa (Italy) Scuola Superiore Sant'Anna, 33, Piazza Martiri della Libertà, San Francesco, Pisa, Toscana, 56127, Italia
#
# Optimized Multi-Fidelity Machine Learning for Quantum Chemical Properties.<br />Fritz Haber Institute, Theory Department, Berlin; Zuse Institute Berlin, Takustraße 7 14195 Berlin Germany Zuse-Institut Berlin (ZIB), 7, Takustraße, Dahlem, Steglitz-Zehlendorf, Berlin, Teltow, 14195, Deutschland
#
# Optimized Multi-Fidelity Machine Learning for Quantum Chemistry.<br />Young Chemists Summit (Salzburg); Paris Lodron University Salzburg, Salzburg, Austria Paris Lodron Universität Salzburg - Kultur- u. Gesellschaftswissenschaftliche Fakultät, 42, Rudolfskai, Altstadt, Salzburg, 5020, Österreich
#
# Optimal Combination and Data Hierarchies in Multifidelity Machine Learning<br />MESIGA25: Numerical Methods in Applied Mathematics, University of Potsdam; Karl-Liebknecht-Straße 24 - 25, 14476 Potsdam, Germany 24-25, Karl-Liebknecht-Straße, Golm, Potsdam, Brandenburg, 14476, Deutschland
#
# Chua diode circuit as a secure communication device using chaos theory.<br />St. Stephen's College: Meera Memorial Paper Presentation; St. Stephen's College, University Enclave, North Campus, Delhi  - 110007, India Saint Stephen's College, North Campus, Central Delhi, Delhi, 110007, India
#
# Delauney Triangulation for Voronoi Partition for implementation in Simulated Mobile Network Data.<br />International Conference Use of R in Official Statistics (uRosConf 2021); Bucharest, Romania București, România
#
# Multifidelity Machine Learning and Active Learning Strategies for Quantum Chemistry.<br />SPP-2363 Annual Meet; Jägerberg 1, 06108 Halle (Saale) Leopoldina, 1, Jägerberg, Neumarktviertel, Nördliche Innenstadt, Halle (Saale), Sachsen-Anhalt, 06108, Deutschland
#
# Multi-Fidelity Machine Learning for Excited State Energies.<br />SIMPLAIX  Workshop on Machine Learning for Multi-scale Molecular Modeling; Schloss-Wolfsbrunnenweg 35, 69118 Heidelberg, Germany HITS, 35, Schloss-Wolfsbrunnenweg, Neuneralm, Schlierbach, Heidelberg, Baden-Württemberg, 69118, Deutschland
#
# simviz: a package to visualize simulated telecommunication mobile network event data.<br />International Conference Use of R in Official Statistics (uRosConf 2021); Bucharest, Romania București, România
#
# Living conditions and Poverty in Italy - 2017. Small Area estimation and machine learning methods.<br />University of Pisa: Erasmus+ & Centro Camilo Dagum & Jean Monnet Chair EU; Via Cosimo Ridolfi 10 – 56124 Pisa Via Cosimo Ridolfi, Porta a Piagge, Pisa, Toscana, 56127, Italia

# %%
# Save the map
m = getorg.orgmap.create_map_obj()
getorg.orgmap.output_html_cluster_map(location_dict, folder_name="talkmap", hashed_usernames=False)
# Out:
# 'Written map to talkmap/'
